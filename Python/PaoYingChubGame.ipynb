# %%
round : int = 0
win  : int = 0
lose : int = 0
draw : int = 0

bot = random.sample(['Rock', 'Paper', 'Scissor'], k = 1)



print("Welcome to Pao Ching Chub game")
print("Game Rule:")
print("You will play against Bot A ")
print("Rock wins Scissors ")
print("Scissors wins Paper")
print("Paper wins Rock ")
print("------------------------------------------------ ")
name = input("Enter Your name:")
print("------------------------------------------------ ")

#player play
while (True):
  print("------------------------------------------------ ")
  try:
    print("Please choose your number")
    print("1.Rock 2. Paper 3. Scissors 4. Exit")
    action = (input("Enter Your number:")) 
   
    print("Play!!!!")
    if action == "1" :
       print("You play: Rock") 
       bot = random.sample(['Rock', 'Paper', 'Scissor'], k = 1)
       print(f"Bot: {bot}")   
       round += 1 
       score({bot})

            

    elif action == "2":
        print("You play: Paper")
        bot = random.sample(['Rock', 'Paper', 'Scissor'], k = 1)
        print(f"Bot: {bot}")
        round += 1
   
    elif action == "3":
        print("You play: Scrissors")
        bot = random.sample(['Rock', 'Paper', 'Scissor'], k = 1)
        print(f"Bot: {bot}")
        round += 1
        
    elif action == "4":
        print("You Exit")
        
    #result
        print(f"Round: {round}")   
        print(f"You win: {win}")
        print(f"You lose: {lose}")
        print(f"You draw: {draw}")   

        break

  except: 
    print("Try Again!")
# Out:
# Welcome to Pao Ching Chub game
# Game Rule:
# You will play against Bot A
# Rock wins Scissors
# Scissors wins Paper
# Paper wins Rock
# ------------------------------------------------
# Enter Your name:4
# ------------------------------------------------
# ------------------------------------------------
# Please choose your number
# 1.Rock 2. Paper 3. Scissors 4. Exit
# Enter Your number:4
# Play!!!!
# You Exit
# Round: 0
# You win: 0
# You lose: 0
# You draw: 0

# %%
import random

#value
round : int = 0
win  : int = 0
lose : int = 0
draw : int = 0

list = ['Rock', 'Paper', 'Scissor']
bot = random.sample(list, k = 1)

#intro
print("Welcome to Pao Ching Chub game")
print("Game Rule:")
print("You will play against Bot A ")
print("Rock wins Scissors ")
print("Scissors wins Paper")
print("Paper wins Rock ")
print("------------------------------------------------ ")
name = input("Enter Your name:")





#loop

while (True):
      print("------------------------------------------------ ")
      action = int(input("Choose your number -> 1.Rock, 2.Paper, 3.Scissor, 4.Exit: "))
      
      if action == 1: #rock
          round += 1
          bot = random.sample(list, k = 1)
          print('You Play:Rock')
          print(f'Bot play:{bot}')
          if bot == ['Rock']:
                print("Draw")
                draw += 1
          elif bot == ['Paper']:
                print("Lose")
                lose += 1
          elif bot == ['Scissor']:
                print("Win")
                win += 1
      elif action == 2: #paper
          round += 1
          bot = random.sample(list, k = 1)
          print('You Play: Paper')
          print(f'Bot play:{bot}')
          if bot == ['Rock']:
                print("Win")
                win += 1
          elif bot == ['Paper']:
                print("Draw")
                draw += 1
          elif bot == ['Scissor']:
                print("Lose")
                lose += 1
      elif action == 3 : #scrissor
          round += 1
          bot = random.sample(list, k = 1)
          print('You Play:Scrissor')
          print(f'Bot play:{bot}')
          if bot == ['Rock']:
                print("Lose")
                lose += 1
          elif bot == ['Paper']:
                print("Win")
                win += 1
          elif bot == ['Scissor']:
                print("Draw")
                draw += 1
      else: 
#result
          print(f"Player: {name}")   
          print(f"Round: {round}")   
          print(f"You win: {win}")
          print(f"You lose: {lose}")
          print(f"You draw: {draw}")   
          break
# Out:
# Welcome to Pao Ching Chub game
# Game Rule:
# You will play against Bot A
# Rock wins Scissors
# Scissors wins Paper
# Paper wins Rock
# ------------------------------------------------
# Enter Your name:beer
# ------------------------------------------------
# Choose your number -> 1.Rock, 2.Paper, 3.Scissor, 4.Exit: 1
# Choose your number -> 1.Rock, 2.Paper, 3.Scissor, 4.Exit: 1
# You Play:Rock
# Bot play:['Paper']
# Lose
# ------------------------------------------------
# You Play:Rock
# Bot play:['Scissor']
# Win
# ------------------------------------------------
# Choose your number -> 1.Rock, 2.Paper, 3.Scissor, 4.Exit: 4
# Player: beer
# Round: 2
# You win: 1
# You lose: 1
# You draw: 0
